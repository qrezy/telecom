# %%
import example_from_book.thinkdsp as tk
import numpy as np

# %% [markdown]
# ## Лабораторное задание 11.3

# %%
wave = sig_proc.read_wave('lab11.wav')
wave.normalize()
wave.plot()

# %%
spectrum = wave.make_spectrum(full=True)
spectrum.plot()

# %%
downsample_factor = 6
sampling_rate = wave.framerate / factor
filter_cutoff = framerate / 2 - 1
spectrum.low_pass(cutoff)
spectrum.plot()

# %%
lowpass_filtered = spectrum.make_wave()
filtered.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def downsample_signal(wave, factor):
    ys = npy.zeros(len(wave))
    ys[::factor] = npy.real(wave.ys[::factor])
    return sig_proc.Wave(ys, framerate=wave.framerate)

# %%
downsampled_wave = sample(filtered, factor)
sampled.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sampled_spec = sampled.make_spectrum(full=True)
sampled_spec.plot()

# %%
sampled_spec.low_pass(cutoff)
sampled_spec.plot()

# %%
sampled_spec.scale(factor)
spectrum.plot()
sampled_spec.plot()

# %%
spectrum.max_diff(sampled_spec)
# Out:
# 1.8749713606747085e-12

# %%
reconstructed_wave = sampled_spec.make_wave()
interpolated.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
filtered.plot()
interpolated.plot()

# %%
filtered.max_diff(interpolated)
# Out:
# 4.683737879773449e-16
