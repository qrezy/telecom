# %%
import example_from_book.thinkdsp as tk

# %% [markdown]
# ## Лабораторное задание 1.2

# %%
audio_data = sig_proc.read_wave("lab1.wav")
time_slice = sound.segment(start=1.25, duration=0.5)

segment.plot()
sig_proc.decorate(
    title="Сегмент",
    xlabel="Время (с)",
    xticks=[i / 10 for i in range(13, 18)] + [1.25, 1.75]
)

# %%
freq_spec = segment.make_spectrum()
spec.plot(high=10_000)
sig_proc.decorate(
    title="Спектр сегмента",
    xlabel="Частота (Гц)"
)

# %% [markdown]
# ### Фильтрация low_pass

# %%
spec_low = spec.copy()
spec_low.low_pass(cutoff=1000, factor=0.01)

filtered_low = spec_low.make_wave()

wave_low.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spec_low.plot(high=10_000)
sig_proc.decorate(
    title="Спектр сегмента (low_pass)",
    xlabel="Частота (Гц)"
)

# %% [markdown]
# ### Фильтрация high_pass

# %%
spec_high = spec.copy()
spec_high.high_pass(cutoff=1000, factor=0.01)

filtered_high = spec_high.make_wave()

wave_high.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spec_high.plot(high=10_000)
sig_proc.decorate(
    title="Спектр сегмента (high_pass)",
    xlabel="Частота (Гц)"
)

# %% [markdown]
# ### Фильтрация bond_stop

# %%
spec_bond = spec.copy()
spec_bond.band_stop(low_cutoff=1000, high_cutoff=2000, factor=0.01)

filtered_band = spec_bond.make_wave()

wave_bond.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spec_bond.plot(high=10_000)
sig_proc.decorate(
    title="Спектр сегмента (bond_stop)",
    xlabel="Частота (Гц)"
)

# %% [markdown]
# ## Лабораторное задание 1.3

# %%
sine_440hz = sig_proc.SinSignal(freq=440, amp=0.5)
cosine_600hz = sig_proc.CosSignal(freq=600, amp=0.3)

combined_signal = sin_440 + cos_600

wave = mix.make_wave(duration=0.5, framerate=16000)

wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
time_slice = wave.segment(start=0, duration=mix.period * 3)
segment.plot()
sig_proc.decorate(
    title="Смесь 440 Гц + 600 Гц",
    xlabel="Время (с)"
)

# %%
freq_spec = wave.make_spectrum()
spec.plot(high=1000)
sig_proc.decorate(
    title="Спектр смеси 440 Гц + 600 Гц",
    xlabel="Частота (Гц)"
)

# %%
sine_880hz = sig_proc.SinSignal(freq=880, amp=0.2)

combined_signal = sin_440 + sin_880

wave = mix.make_wave(duration=0.5, framerate=16000)

wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
time_slice = wave.segment(start=0, duration=mix.period * 3)
segment.plot()
sig_proc.decorate(
    title="Смесь 440 Гц + 880 Гц",
    xlabel="Время (с)"
)

# %%
freq_spec = wave.make_spectrum()
spec.plot(high=1000)
sig_proc.decorate(
    title="Спектр смеси 440 Гц + 880 Гц",
    xlabel="Частота (Гц)"
)

# %% [markdown]
# ## Лабораторное задание 1.4

# %%
def time_stretch(wave_, factor):
    wave_.ts *= factor
    wave_.framerate /= factor

# %%
signal = sig_proc.SinSignal(freq=440)
wave = signal.make_wave(duration=1.0, framerate=16000)

print('Длительность:', wave.duration)
print('Частота кадров:', wave.framerate)

stretch(wave, 2.0)

print('\nНовая длительность:', wave.duration)
print('Новая частота кадров:', wave.framerate)

wave.make_audio()
# Out:
# Длительность: 1.0
# Частота кадров: 16000
#
# Новая длительность: 2.0
# Новая частота кадров: 8000.0
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
